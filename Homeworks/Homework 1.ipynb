# %%
# Global AI HUb Introduction to Python Homework 1.1
list1 = [1,3,'strawberry',7,'kiwi',14,19,12,23,'apple']
print('İlk liste:',list1)
list = list1
list1[0:5],list1[5:11] = list1[5:11],list1[0:5]
print('İkinci liste:',list1)
# Out:
# İlk liste: [1, 3, 'strawberry', 7, 'kiwi', 14, 19, 12, 23, 'apple']
# İkinci liste: [14, 19, 12, 23, 'apple', 1, 3, 'strawberry', 7, 'kiwi']

# %%
#Global AI Hub Introduction to Python Homework 1.2
n= int(input('Lütfen tek basamaklı bir sayı giriniz.'))
x=0
while x<=n:
    print(x)
    x=x+2
# Out:
# Lütfen tek basamaklı bir sayı giriniz. 7
# 0
# 2
# 4
# 6
